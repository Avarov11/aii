# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('D:/c/titanic-passengers.csv', sep = ';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.Embarked.fillna(df.Embarked.mode()[0], inplace = True)

# %%
df
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
import seaborn as sns
sns.heatmap(df.corr(),cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df[
    "Survived"]=df["Survived"].map({"Yes":1, "No":0})
df["Sex"]=df["Sex"].map({"female":1,"male":0})

# %%
sns.boxplot(df['Sex'], df["Age"])
# Out:
# D:\course\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
grid= sns.FacetGrid(df,col="Sex")
grid.map(plt.hist,"Age",bins=10)

# %%
df.shape
# Out:
# (891, 12)

# %%
df[["Sex","Age"]].groupby("Sex").mean()
# Out:
#            Age
# Sex
# 0    30.505824
# 1    28.216730

# %%
df.Age.sum()
# Out:
# 26461.91382352941

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    0  28.0      0      0      248740  13.0000    NaN        S
# 1    0  25.0      0      0      348123   7.6500  F G73        S
# 2    0  20.0      0      0      350050   7.8542    NaN        S
# 3    1  29.0      0      4      349909  21.0750    NaN        S
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
grid= sns.FacetGrid(df,col="Survived")
grid.map(plt.hist,"Sex",bins=10)

# %%
df.Survived.sum()
# Out:
# 342

# %%
grid= sns.FacetGrid(df,col="Survived")
grid.map(plt.hist,"Age",bins=10)

# %%
plot_correlation_map( df )

# %%
df[["Survived","Sex","Age"]].groupby(["Sex","Survived"]).mean()
# Out:
#                     Age
# Sex Survived
# 0   0         31.175224
#     1         27.631705
# 1   0         26.023272
#     1         28.979263

# %%
grid = sns.FacetGrid(df, row="Sex", col="Survived", size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Age', alpha=.5, ci=None)
grid.add_legend()
# Out:
# D:\course\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# D:\course\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid= sns.FacetGrid(df,col="Survived",row="Sex")
grid.map(plt.hist,"Age",bins=10)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.000000      0
# 2                               Jensen, Mr. Hans Peder    0  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                               Davidson, Mr. Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 887                              Sirayanian, Mr. Orsen    0  22.000000      0
# 888                                Cacic, Miss. Marija    1  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mr",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
# for name in df['Name']:
#     titles.add(name.split(',')[1].split('.')[0].strip())
# print(titles)

# %%
df['Title'] = df['Name'].map(lambda name:name.split(',')[1].split('.')[0].strip())
df['Title'] = df.Title.map(Title_Dictionary)
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    0  28.0      0      0      248740  13.0000    NaN        S    Mr
# 1    0  25.0      0      0      348123   7.6500  F G73        S    Mr
# 2    0  20.0      0      0      350050   7.8542    NaN        S    Mr
# 3    1  29.0      0      4      349909  21.0750    NaN        S   Mrs
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S    Mr

# %%
family=[]
df['family']=df["SibSp"]+df["Parch"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.000000      0
# 2                               Jensen, Mr. Hans Peder    0  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                               Davidson, Mr. Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 887                              Sirayanian, Mr. Orsen    0  22.000000      0
# 888                                Cacic, Miss. Marija    1  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked Title  family
# 0        0      248740  13.0000    NaN        S    Mr       0
# 1        0      348123   7.6500  F G73        S    Mr       0
# 2        0      350050   7.8542    NaN        S    Mr       0
# 3        4      349909  21.0750    NaN        S   Mrs       4
# 4        0  F.C. 12750  52.0000    B71        S    Mr       1
# ..     ...         ...      ...    ...      ...   ...     ...
# 886      0      237736  30.0708    NaN        C   Mrs       1
# 887      0        2669   7.2292    NaN        C    Mr       0
# 888      0      315084   8.6625    NaN        S  Miss       0
# 889      0      349215   7.8958    NaN        S    Mr       0
# 890      0      250655  26.0000    NaN        S  Miss       0
#
# [891 rows x 14 columns]

# %%
x=df.SibSp.sum()
y=df.Parch.sum()
x+y
# Out:
# 806

# %%
plot_correlation_map( df )

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.000000      0
# 2                               Jensen, Mr. Hans Peder    0  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                               Davidson, Mr. Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 887                              Sirayanian, Mr. Orsen    0  22.000000      0
# 888                                Cacic, Miss. Marija    1  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked Title  family
# 0        0      248740  13.0000    NaN        S    Mr       0
# 1        0      348123   7.6500  F G73        S    Mr       0
# 2        0      350050   7.8542    NaN        S    Mr       0
# 3        4      349909  21.0750    NaN        S   Mrs       4
# 4        0  F.C. 12750  52.0000    B71        S    Mr       1
# ..     ...         ...      ...    ...      ...   ...     ...
# 886      0      237736  30.0708    NaN        C   Mrs       1
# 887      0        2669   7.2292    NaN        C    Mr       0
# 888      0      315084   8.6625    NaN        S  Miss       0
# 889      0      349215   7.8958    NaN        S    Mr       0
# 890      0      250655  26.0000    NaN        S  Miss       0
#
# [891 rows x 14 columns]

# %%
#logisticccc

# %%
df["Survived"].map({"Yes":1,"No":0})
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title  family
# 0    0  28.0      0      0      248740  13.0000    NaN        S    Mr       0
# 1    0  25.0      0      0      348123   7.6500  F G73        S    Mr       0
# 2    0  20.0      0      0      350050   7.8542    NaN        S    Mr       0
# 3    1  29.0      0      4      349909  21.0750    NaN        S   Mrs       4
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S    Mr       1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.000000      0
# 2                               Jensen, Mr. Hans Peder    0  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                               Davidson, Mr. Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 887                              Sirayanian, Mr. Orsen    0  22.000000      0
# 888                                Cacic, Miss. Marija    1  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked Title  family
# 0        0      248740  13.0000    NaN        S    Mr       0
# 1        0      348123   7.6500  F G73        S    Mr       0
# 2        0      350050   7.8542    NaN        S    Mr       0
# 3        4      349909  21.0750    NaN        S   Mrs       4
# 4        0  F.C. 12750  52.0000    B71        S    Mr       1
# ..     ...         ...      ...    ...      ...   ...     ...
# 886      0      237736  30.0708    NaN        C   Mrs       1
# 887      0        2669   7.2292    NaN        C    Mr       0
# 888      0      315084   8.6625    NaN        S  Miss       0
# 889      0      349215   7.8958    NaN        S    Mr       0
# 890      0      250655  26.0000    NaN        S  Miss       0
#
# [891 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
x=df[["Age",'Sex']]
y=df['Survived']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
logreg = LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
print("accuracy={:.2f}".format(logreg.score(x_test,y_test)))
# Out:
# accuracy=0.83

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.000000      0
# 2                               Jensen, Mr. Hans Peder    0  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                               Davidson, Mr. Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 887                              Sirayanian, Mr. Orsen    0  22.000000      0
# 888                                Cacic, Miss. Marija    1  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked Title  family
# 0        0      248740  13.0000    NaN        S    Mr       0
# 1        0      348123   7.6500  F G73        S    Mr       0
# 2        0      350050   7.8542    NaN        S    Mr       0
# 3        4      349909  21.0750    NaN        S   Mrs       4
# 4        0  F.C. 12750  52.0000    B71        S    Mr       1
# ..     ...         ...      ...    ...      ...   ...     ...
# 886      0      237736  30.0708    NaN        C   Mrs       1
# 887      0        2669   7.2292    NaN        C    Mr       0
# 888      0      315084   8.6625    NaN        S  Miss       0
# 889      0      349215   7.8958    NaN        S    Mr       0
# 890      0      250655  26.0000    NaN        S  Miss       0
#
# [891 rows x 14 columns]

# %%
import seaborn as sns
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
y=df.Age
x=df.Survived

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
def plot_roc_curve(true_y,y_prob):
    true_y,y_prob, thresholds = roc_curve(true_y,y_prob)
    plt.plot(true_y,y_prob)
    plt.xlabel("Age")
    plt.ylabel("Survived")

# %%
plot_roc_curve(y_test, y_pred)
print(f'model 2 AUC score: {roc_auc_score(y_test, y_pred)}')
# Out:
# model 2 AUC score: 0.7960179324894515
